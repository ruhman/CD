# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib

dados = pd.read_table("pes2013A.txt",sep=" ")

# %%
dados
# Out:
#         V0101  UF  V0102  V0103  V0301  V0302  V8005  V0404  V4011  V0412  \
# 1        2013  11     15      3      1      4     42      2    5.0      2
# 2        2013  11     15      4      1      4     64      8    7.0      2
# 3        2013  11     15      4      2      4     13      4    0.0      2
# 4        2013  11     15      5      1      2     23      8    0.0      2
# 5        2013  11     15      5      2      4     19      8    0.0      2
# 6        2013  11     15      5      3      4     17      8    0.0      2
# 7        2013  11     15      6      1      2     59      4    NaN      2
# 8        2013  11     15      6      2      4     56      2    NaN      2
# 9        2013  11     15      7      1      2     25      8    1.0      2
# 10       2013  11     15      7      2      4     23      2    1.0      2
# 11       2013  11     15      7      3      4      5      2    NaN      4
# 12       2013  11     15      8      1      2     37      2    NaN      2
# ...

# %%
dados["V8005"]
# Out:
# 1         42
# 2         64
# 3         13
# 4         23
# 5         19
# 6         17
# 7         59
# 8         56
# 9         25
# 10        23
# 11         5
# 12        37
# 13        25
# 14         4
# 15        50
# 16        23
# 17        28
# 18        41
# 19        34
# 20        17
# 21        15
# 22         1
# 23        51
# 24        44
# 25         8
# 26        36
# 27        49
# 28         9
# 29        25
# 30        57
#           ..
# 362526    10
# 362527    33
# 362528    43
# 362529    12
# 362530     9
# 362531     7
# 362532    42
# 362533    38
# 362534    18
# 362535    15
# 362536    14
# 362537    18
# 362538    23
# 362539    50
# 362540    39
# 362541    21
# 362542    22
# 362543    35
# 362544    49
# 362545    13
# 362546    54
# 362547    48
# 362548     5
# 362549    17
# 362550    30
# 362551    33
# 362552    11
# 362553     2
# 362554    32
# 362555     6
# Name: V8005, dtype: int64

# %%
c = dados[(dados.V8005 >= 16) & (dados.V8005 <= 25)] #pegar apenas os jovens

# %%
d = c[c.V0302 == 4] #pegar só as mulheres

# %%
e = d[d.V4802>=10] #pegar apenas quem tem diploma de ensino medio sem faculdade

# %%
f = e[e.V6002==4] #pegar alunas de rede privada

# %%
g = f[f.V0601 ==1] #pegar apenas as que sabem ler

# %%
g = g.UF.value_counts() #contar quantas "potenciais alunas" tem em cada estado

# %%
g #UF 35 é São Paulo
# Out:
# 35    501
# 31    365
# 43    334
# 33    313
# 41    233
# 29    209
# 23    203
# 53    185
# 52    183
# 26    181
# 42    169
# 15    167
# 13    128
# 51     82
# 32     82
# 50     79
# 11     73
# 28     72
# 17     61
# 21     59
# 25     59
# 27     52
# 22     51
# 16     47
# 12     40
# 24     37
# 14     28
# Name: UF, dtype: int64
