# %%
# %matplotlib inline

import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import pandas as pd
import numpy as np

import statsmodels.api as sm1 #Usa OLS com X como matriz de planejamento
import statsmodels.formula.api as sm  #Usa OLS como no R

print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# /Users/daniruhman/Dropbox/Insper/Ciencia dos Dados/CD-Daniel Ruhman-Git/Projeto3

# %%
mortalidade = pd.read_excel('indicatorgapminderunder5mortality.xlsx',index_col=0)

# %%
mortalidade.head()
# Out:
#                          1800    1801    1802    1803    1804    1805    1806  \
# Under five mortality
# Abkhazia                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Afghanistan            468.58  468.58  468.58  468.58  468.58  468.58  469.98
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Albania                375.20  375.20  375.20  375.20  375.20  375.20  375.20
# Algeria                460.21  460.21  460.21  460.21  460.21  460.21  460.21
#
#                          1807    1808    1809  ...    2006   2007   2008  \
# Under five mortality                           ...
# Abkhazia                  NaN     NaN     NaN  ...     NaN    NaN    NaN
# Afghanistan            469.98  469.98  469.98  ...   116.3  113.2  110.4
# Akrotiri and Dhekelia     NaN     NaN     NaN  ...     NaN    NaN    NaN
# Albania                375.20  375.20  375.20  ...    19.5   18.7   17.9
# Algeria                460.21  460.21  460.21  ...    32.1   30.7   29.5
#
#                         2009   2010   2011  2012  2013  2014  2015
# Under five mortality
# Abkhazia                 NaN    NaN    NaN   NaN   NaN   NaN   NaN
# Afghanistan            107.6  105.0  102.3  99.5  96.7  93.9  91.1
# Akrotiri and Dhekelia    NaN    NaN    NaN   NaN   NaN   NaN   NaN
# Albania                 17.3   16.6   16.0  15.5  14.9  14.4  14.0
# Algeria                 28.4   27.4   26.6  25.8  25.2  24.6  24.0
#
# [5 rows x 216 columns]

# %%
hdi = pd.read_excel('Indicator_HDI.xlsx',index_col=0)

# %%
hdi.head()
# Out:
#                         1980   1990   2000   2005   2006   2007   2008   2009  \
# HDI
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            0.198  0.246  0.230  0.340  0.354  0.363  0.370  0.387
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                  NaN  0.656  0.691  0.721  0.724  0.729  0.733  0.734
# Algeria                0.454  0.551  0.624  0.667  0.673  0.680  0.686  0.691
#
#                         2011
# HDI
# Abkhazia                 NaN
# Afghanistan            0.398
# Akrotiri and Dhekelia    NaN
# Albania                0.739
# Algeria                0.698

# %%
pib = pd.read_excel('GDPpercapitaconstant2000US.xlsx',index_col=0)

# %%
pib.head()
# Out:
#                                            1960         1961        1962  \
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN         NaN
# Afghanistan                                 NaN          NaN         NaN
# Akrotiri and Dhekelia                       NaN          NaN         NaN
# Albania                                     NaN          NaN         NaN
# Algeria                             1280.384828  1085.414612  855.947986
#
#                                           1963         1964         1965  \
# Income per person (fixed 2000 US$)
# Abkhazia                                   NaN          NaN          NaN
# Afghanistan                                NaN          NaN          NaN
# Akrotiri and Dhekelia                      NaN          NaN          NaN
# Albania                                    NaN          NaN          NaN
# Algeria                             1128.41578  1170.323896  1215.015783
#
#                                            1966         1967         1968  \
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                                     NaN          NaN          NaN
# Algeria                             1127.614288  1200.558225  1291.863983
#
#                                            1969     ...              2002  \
# Income per person (fixed 2000 US$)                  ...
# Abkhazia                                    NaN     ...               NaN
# Afghanistan                                 NaN     ...               NaN
# Akrotiri and Dhekelia                       NaN     ...               NaN
# Albania                                     NaN     ...       1313.722725
# Algeria                             1359.491003     ...       1871.921986
#
#                                            2003         2004         2005  \
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                             1381.040832  1454.022854  1525.723589
# Algeria                             1971.512803  2043.135713  2115.186028
#
#                                            2006         2007         2008  \
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                             1594.495067  1681.613910  1804.419415
# Algeria                             2124.957754  2155.485231  2173.787903
#
#                                            2009         2010         2011
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                             1857.352947  1915.424459  1965.707230
# Algeria                             2192.703976  2231.980246  2255.225482
#
# [5 rows x 52 columns]

# %%
mortalidade.shape
# Out:
# (275, 216)

# %%
mortalidade=mortalidade[~np.isnan(mortalidade[2011])]
mortalidade.shape
# Out:
# (211, 216)

# %%
hdi.shape
# Out:
# (270, 9)

# %%
hdi=hdi[~np.isnan(hdi[2011])]
hdi.shape
# Out:
# (187, 9)

# %%
pib.shape
# Out:
# (275, 52)

# %%
pib=pib[~np.isnan(pib["2011"])]
pib.shape
# Out:
# (175, 52)

# %%
dados = pd.DataFrame()
dados["Mortalidade"] = mortalidade[2011]
dados["Pib/C"] = pib["2011"]
dados["HDI"] = hdi[2011]
dados.shape
# Out:
# (211, 3)

# %%
dados=dados[~np.isnan(dados.Mortalidade)]
dados=dados[~np.isnan(dados["Pib/C"])]
dados=dados[~np.isnan(dados.HDI)]
dados.shape
# Out:
# (171, 3)

# %%
dados.head()
# Out:
#                       Mortalidade         Pib/C    HDI
# Under five mortality
# Albania                      16.0   1965.707230  0.739
# Algeria                      26.6   2255.225482  0.698
# Angola                      177.3    629.955306  0.486
# Antigua and Barbuda           9.5   9977.957073  0.764
# Argentina                    14.2  11601.630223  0.797

# %%
plt.scatter(dados["Mortalidade"],np.log(dados["Pib/C"]), alpha=0.7) 
plt.ylabel("Pib per Capita")
plt.xlabel("Mortalidade Infantil")
plt.show()

plt.scatter(dados["Mortalidade"],dados["HDI"], alpha=0.7)
plt.ylabel("IDH")
plt.xlabel("Mortalidade Infantil")
plt.show()

# %%
dados.corr(method='pearson')
# Out:
#              Mortalidade     Pib/C       HDI
# Mortalidade     1.000000 -0.496680 -0.877618
# Pib/C          -0.496680  1.000000  0.693445
# HDI            -0.877618  0.693445  1.000000

# %%
y=dados.Mortalidade
X=dados.iloc[:,(1,2)]
X=sm1.add_constant(X)  # Adds a constant term to the predictor
X.head()

model=sm1.OLS(y, X)
fit=model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Mortalidade   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.792
# Method:                 Least Squares   F-statistic:                     324.4
# Date:                Sun, 04 Dec 2016   Prob (F-statistic):           2.02e-58
# Time:                        12:48:30   Log-Likelihood:                -729.09
# No. Observations:                 171   AIC:                             1464.
# Df Residuals:                     168   BIC:                             1474.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const        179.5968      6.332     28.362      0.000       167.096   192.098
# Pib/C          0.0008      0.000      4.439      0.000         0.000     0.001
# HDI         -224.1058     10.596    -21.151      0.000      -245.024  -203.188
# ==============================================================================
# Omnibus:                       84.399   Durbin-Watson:                   2.229
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              567.069
# Skew:                           1.683   Prob(JB):                    7.29e-124
# Kurtosis:                      11.262   Cond. No.                     1.21e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X
# Out:
#                           const         Pib/C    HDI
# Under five mortality
# Albania                       1   1965.707230  0.739
# Algeria                       1   2255.225482  0.698
# Angola                        1    629.955306  0.486
# Antigua and Barbuda           1   9977.957073  0.764
# Argentina                     1  11601.630223  0.797
# Armenia                       1   1384.085162  0.716
# Australia                     1  25306.824938  0.929
# Austria                       1  27266.403350  0.885
# Azerbaijan                    1   2338.896558  0.731
# Bahamas                       1  19466.990524  0.771
# Bangladesh                    1    588.369178  0.500
# Belarus                       1   2890.345675  0.756
# Belgium                       1  24733.626956  0.886
# Belize                        1   3490.234069  0.699
# Benin                         1    378.051792  0.427
# Bhutan                        1   1445.760002  0.522
# Bolivia                       1   1276.128614  0.663
# Bosnia and Herzegovina        1   2225.290153  0.733
# Botswana                      1   4377.555741  0.633
# Brazil                        1   4803.398244  0.718
# Brunei                        1  17301.338687  0.838
# Bulgaria                      1   2618.876037  0.771
# Burkina Faso                  1    285.803026  0.331
# Burundi                       1    140.812504  0.316
# Cambodia                      1    590.452112  0.523
# Cameroon                      1    665.798233  0.482
# Canada                        1  25933.288335  0.908
# Cape Verde                    1   2038.880104  0.568
# Central African Republic      1    232.623253  0.343
# Chad                          1    301.401709  0.328
# ...                         ...           ...    ...
# South Africa                  1   3825.093781  0.619
# Spain                         1  15428.320984  0.878
# Sri Lanka                     1   1402.121673  0.691
# Sudan                         1    561.842721  0.408
# Swaziland                     1   1813.544908  0.522
# Sweden                        1  33630.246037  0.904
# Switzerland                   1  39170.413709  0.903
# Tajikistan                    1    295.360131  0.607
# Tanzania                      1    473.881236  0.466
# Thailand                      1   2699.123242  0.682
# Timor-Leste                   1    451.982599  0.495
# Togo                          1    273.107513  0.435
# Tonga                         1   2162.151892  0.704
# Trinidad and Tobago           1  10047.903186  0.760
# Tunisia                       1   3050.885999  0.698
# Turkey                        1   5741.410398  0.699
# Turkmenistan                  1   1370.427756  0.686
# Uganda                        1    392.708800  0.446
# Ukraine                       1   1094.681152  0.729
# United Arab Emirates          1  21058.436426  0.846
# United Kingdom                1  28272.406612  0.863
# United States                 1  37691.027331  0.910
# Uruguay                       1   9581.056590  0.783
# Uzbekistan                    1    992.761365  0.641
# Vanuatu                       1   1522.528302  0.617
# Venezuela                     1   5671.912202  0.735
# Vietnam                       1    757.400929  0.593
# Yemen                         1    528.398673  0.462
# Zambia                        1    443.920631  0.430
# Zimbabwe                      1    347.745661  0.376
#
# [171 rows x 3 columns]

# %%
#Teste de White
#ver link https://pt.wikipedia.org/wiki/Teste_de_White
#y estimados
y_hat = fit.predict(X)

#Resíduos quadráticos
res2=(y-y_hat)**2

sm1.stats.diagnostic.het_white(res2,X)
# Out:
# (2.8772660000026011,
#  0.71890092343777245,
#  0.56476465580251278,
#  0.72690368287146656)
